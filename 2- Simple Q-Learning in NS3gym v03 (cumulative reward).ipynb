# %%
import gym
import tensorflow as tf
import tensorflow.contrib.slim as slim
import numpy as np
import random
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
from ns3gym import ns3env
# Out:
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sheila/anaconda3/envs/environment_py3_7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed = 42
np.random.seed(seed)
tf.random.set_random_seed(seed)#tf.random.set_seed(seed)
random.seed(seed)

# %%
#  collisionTh = 7
#  collisions = 19

env = gym.make('ns3-v0') # environment ID

# numero de estados
s_num = env.observation_space.shape[0]

# numero de acoes
a_num = env.action_space.n

print("\n")
print("Numero de Estados: ", s_num)
print("Numero de Acoes: ", a_num) 

"""
# ambiente anterior
Q = np.array(np.zeros([4,4]))
"""

# ambiente atual
Q_table = np.zeros([s_num, a_num])
# Out:
# Got new port for ns3gm interface:  5913
#
#
# Numero de Estados:  4
# Numero de Acoes:  4

# %%
def choose_action(s, s_num, epsilon):
# Selecione a ação com o maior valor Q.
    if np.random.uniform() < epsilon:
        a = int(np.max(Q_table[np.argwhere(s)[0][0]]))
# Selecione uma ação aleatóriamente.
    else:
        a = np.random.randint(0, s_num)
    return a

# %%
numOfEpisodes = 200
numTimeSlots = 495

discount_rate = 0.95 # gamma 0.95; 0.93
# learning rate
learning_rate0 = 0.05 # 0.05 # alpha; 0.4
learning_rate_decay = 0.1 # 0.1 alpha_decay

# exploration rate
# epsilon = 0.5               
# epsilon_min = 0.01
# epsilon_decay = 0.999

epsilon = 1 # Epsilon-greedy algorithm in initialized at 1 meaning every step is random at the start
max_epsilon = 1 # You can't explore more than 100% of the time
min_epsilon = 0.01 # At a minimum, we'll always explore 1% of the time
decay = 0.01

time_history = []
rew_history = []

episode_reward = np.zeros((numOfEpisodes,))
max_reward =  np.zeros((numOfEpisodes,))


for episode in range(numOfEpisodes):
    
    print('Episode:', episode)
    rewardsum = 0
    # s - Current State
    s = env.reset()
    s = np.reshape(s, [1, s_num])
    
    
    for iteration in range(numTimeSlots):
        
        # a - Action   
        a = choose_action(s, s_num, epsilon) # acao    
    
        # Step
        next_state, reward, done, _ = env.step(a) # toma uma ação  no ambiente a cada passo de tempo
               
        
        next_state = np.array(next_state)
        
        # Accumulate reward.
        episode_reward[episode] += reward
        
    
        # state index
        s_index   = np.argwhere(s==1)[0][0] 
        
        # next-state index
        n_s_index   = np.argwhere(next_state==1)[0][0]            
        
        
        # next-state Q-valor Maximo
        n_s_Qmax = np.max(Q_table[n_s_index])
    
       
        print("Time Slot    :", iteration)
        print("----------------------", "\n")
        print("Current State:", s, "-->", s_index)
        print("Action       :", a)
        print("Next state   :", next_state, "-->", n_s_index) #, "-->", (s + 1) % 4
        print("Reward       :", reward)
        print("Gameover     :", done)
        print("----------------------", "\n")  
    
    
        learning_rate = learning_rate0 / (1 + iteration * learning_rate_decay)# passo de aprendizagem
    
        # Calculates and updates the Q-table values
        Q_table[s_index, a] = (1 - learning_rate) * Q_table[s_index, a] + learning_rate * (
        reward + discount_rate * n_s_Qmax)
        
            
        rewardsum += reward  
        
        print("Tabela do Q-value Maximo")
        print(Q_table, "\n")
        print("Acao otima para cada canal:", np.argmax(Q_table, axis=1), "\n")
        print("---------------------------", "\n")
        
        if done == True:
            print('########## Game Over ##########')
            break
                   
    
        # updates the current state
        s = next_state
        
        # updates the exploration rate
        #if epsilon > epsilon_min: epsilon *= epsilon_decay
    # Decrease epsilon along the way.
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-dec
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 0
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.15425823 3.56770602]
#  [2.75159068 3.17286365 1.45264411 3.01128562]
#  [2.65930446 2.86291323 3.21732409 1.02937928]
#  [1.30280232 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 33
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 1
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.15425823 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.01128562]
#  [2.65930446 2.86291323 3.21732409 1.02937928]
#  [1.30280232 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 34
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 3
# Next state   : [0 0 0 1] --> 3
# Reward       : -1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.15425823 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.01128562]
#  [2.65930446 2.86291323 3.21732409 1.04083169]
#  [1.30280232 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 35
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 0
# Next state   : [1 0 0 0] --> 0
# Reward       : -1.0
# Gameover     : True
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.15425823 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.01128562]
#  [2.65930446 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# ########## Game Over ##########
# Episode: 198
# Got new port for ns3gm interface:  5582
# Time Slot    : 0
# ----------------------
#
# Current State: [[1 0 0 0]] --> 0
# Action       : 2
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.01128562]
#  [2.65930446 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 1
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 3
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.05879345]
#  [2.65930446 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 2
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 0
# Next state   : [0 0 0 1] --> 3
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.13017317]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 3
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 3
# Next state   : [1 0 0 0] --> 0
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.56770602]
#  [2.75159068 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.17860192]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 4
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 3
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.58400156]
#  [2.75159068 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.17860192]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 5
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 0
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.58400156]
#  [2.79508626 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.21732409 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.17860192]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 6
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 2
# Next state   : [0 0 0 1] --> 3
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.58400156]
#  [2.79508626 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.24294494 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.17860192]]
#
# Acao otima para cada canal: [3 1 2 2]
#
# ---------------------------
#
# Time Slot    : 7
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 3
# Next state   : [1 0 0 0] --> 0
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.58400156]
#  [2.79508626 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.24294494 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 8
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 3
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.59622321]
#  [2.79508626 3.183138   1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.24294494 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 9
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 1
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.24294494 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 10
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 2
# Next state   : [0 0 0 1] --> 3
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.26321965 1.04083169]
#  [1.31487475 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 11
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 0
# Next state   : [1 0 0 0] --> 0
# Reward       : -1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.45662702 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 12
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 1
# Next state   : [1 1 0 0] --> 0
# Reward       : -1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.11530333 1.47844031 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 13
# ----------------------
#
# Current State: [1 1 0 0] --> 0
# Action       : 0
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.47844031 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.71671641 2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 14
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 0
# Next state   : [0 0 0 1] --> 3
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.47844031 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.21466662]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 15
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 3
# Next state   : [1 0 0 0] --> 0
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.47844031 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.23870152]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 16
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 1
# Next state   : [0 1 0 0] --> 1
# Reward       : -1.0
# Gameover     : True
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.19774437 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.23870152]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# ########## Game Over ##########
# Episode: 199
# Got new port for ns3gm interface:  5483
# Time Slot    : 0
# ----------------------
#
# Current State: [[1 0 0 0]] --> 0
# Action       : 2
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.24017828 3.59622321]
#  [2.79508626 3.20676062 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.23870152]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 1
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 1
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.24017828 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.26321965 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.23870152]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 2
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 2
# Next state   : [0 0 0 1] --> 3
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.24017828 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.29711743 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.23870152]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 3
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 3
# Next state   : [1 0 0 0] --> 0
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.24017828 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.29711743 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.28399808]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 4
# ----------------------
#
# Current State: [1 0 0 0] --> 0
# Action       : 2
# Next state   : [0 1 0 0] --> 1
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.27035037 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.05879345]
#  [2.7445751  2.86291323 3.29711743 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.28399808]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 5
# ----------------------
#
# Current State: [0 1 0 0] --> 1
# Action       : 3
# Next state   : [0 0 1 0] --> 2
# Reward       : 1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.27035037 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.09457572]
#  [2.7445751  2.86291323 3.29711743 1.04083169]
#  [1.34110183 2.86927934 3.19704351 3.28399808]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 6
# ----------------------
#
# Current State: [0 0 1 0] --> 2
# Action       : 3
# Next state   : [0 0 0 1] --> 3
# Reward       : -1.0
# Gameover     : False
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.27035037 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.09457572]
#  [2.7445751  2.86291323 3.29711743 1.07454939]
#  [1.34110183 2.86927934 3.19704351 3.28399808]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# Time Slot    : 7
# ----------------------
#
# Current State: [0 0 0 1] --> 3
# Action       : 0
# Next state   : [1 0 0 0] --> 0
# Reward       : -1.0
# Gameover     : True
# ----------------------
#
# Tabela do Q-value Maximo
# [[3.13671105 1.48936305 3.27035037 3.59622321]
#  [2.79508626 3.24736508 1.45264411 3.09457572]
#  [2.7445751  2.86291323 3.29711743 1.07454939]
#  [1.3727286  2.86927934 3.19704351 3.28399808]]
#
# Acao otima para cada canal: [3 1 2 3]
#
# ---------------------------
#
# ########## Game Over ##########

# %%
plt.plot(episode_reward, label='Actual reward')
plt.plot(max_reward, '.', label='Max. reward')
plt.xlabel('Episode')
plt.ylabel('Accumulated Reward')
plt.grid()
plt.legend()
plt.show()
