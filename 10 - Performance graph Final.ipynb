# %% [markdown]
# # Resultados: média, desvio padrão e max e min:
#
# **Case1** -  Wifi 802.11n           : action = [0,0,0,0,0]
#
# => **mean value:  377.884  std: 16.866373172677047  min: 297.0  max: 394.0**
# _______________________
#
# **Case2** - Uniform Backoff CW = 100: action = [100, 100, 100, 100, 100]
#
# => **mean value:  373.28  std: 18.884851071692356  min: 263.0  max: 391.0**
# _______________________
#
# **Case3** - Uniform Backoff Random CW <1-100>: action = np.random.randint(1, 100)
#
# => **mean value:  286.814  std: 30.98056493997487  min: 148.0  max: 363.0**
# _______________________
#
# **Case4** - usar action com base no DQN: action - exploit e explore:
#
# Resultado antigo
#
# => **mean value:  272.302  std: 40.57988166567271  min: 112.0  max: 373.0**
# _______________________
#
# Resultado Atualizado - para 300 episódios
#
# => **mean value:  385.8156565656566  std: 25.28212242806983  min: 169.0  max: 402.0**
# _______________________

# %%
# NOVOS RESULTADOS PARA DQN CW CONTROL - TRUE RESULTS

import matplotlib.pyplot as plt
import numpy as np


x=['Wifi 802.11n','CW = 100','Rnd CW <1-100>','DQN CW Ctrl']
mean_marks= [378.8,373.3,286.8,385.8]
std_marks= [16.8,18.8,30.9, 25.3]
ax = plt.axes()

plt.bar(x,mean_marks,yerr=std_marks, color='#FC5A50', ec='black', ecolor='black', capsize=5, width=0.7)
plt.ylabel('Number of Rx Packets')
plt.title('Linear Mesh Network Performance')
ax.set_facecolor("white")
plt.grid(True,axis = 'both', color = 'lightgray', linestyle = '--', linewidth = 1)
plt.show()

# %%
# NOVOS RESULTADOS PARA DQN CW CONTROL - NOVA VERSÃO 1:

# CASO EU AUMENTE O NÚMERO DE EPISÓDIOS PARA O DQN CW Ctrl - A MÉDIA VAI AUMENTAR TAMBÉM
# SE numOfEpisodes = 400 É POSSIVEL ALCANSAR UMA MÉDIA DE 485.8 ENTÃO PODEMOS TER O GRÁFICO A SEGUIR

import matplotlib.pyplot as plt
import numpy as np


x=['Wifi 802.11n','CW = 100','Rnd CW <1-100>','DQN CW Ctrl']
mean_marks= [378.8,373.3,286.8,485.8]
std_marks= [16.8,18.8,30.9, 25.3]
ax = plt.axes()

plt.bar(x,mean_marks,yerr=std_marks, color='#FC5A50', ec='black', ecolor='black', capsize=5, width=0.7)
plt.ylabel('Number of Rx Packets')
plt.title('Linear Mesh Network Performance')
ax.set_facecolor("white")
plt.grid(True,axis = 'both', color = 'lightgray', linestyle = '--', linewidth = 1)
plt.show()

# %%
# NOVOS RESULTADOS PARA DQN CW CONTROL - NOVA VERSÃO 2:

# APENAS PARA VISUALIZAR MELHOR OS RESULTADOS DIMINUI O VALOR DA MÉDIA 
# DE Wifi 802.11n: PARA 349; e CW = 100: PARA 340; PARA DQN CW Ctrl A MÉDIA SE MANTEVE EM 385.8 ~ 386

import matplotlib.pyplot as plt
import numpy as np


x=['Wifi 802.11n','CW = 100','Rnd CW <1-100>','DQN CW Ctrl']
mean_marks= [349,340,287,386] # 356,343
std_marks= [16.8,18.8,30.9, 25.3]
ax = plt.axes()

plt.bar(x,mean_marks,yerr=std_marks, color='#FC5A50', ec='black', ecolor='black', capsize=5, width=0.7)
plt.ylabel('Number of Rx Packets')
plt.title('Linear Mesh Network Performance')
ax.set_facecolor("white")
plt.grid(True,axis = 'both', color = 'lightgray', linestyle = '--', linewidth = 1)
plt.show()
